# %% [markdown]
# # Introduction to W&B
#
# <!--- @wandbcode{dlai_01} -->
#
# We will add `wandb` to sprite classification model training, so that we can track and visualize important metrics, gain insights into our model's behavior and make informed decisions for model improvements. We will also see how to compare and analyze different experiments, collaborate with team members, and reproduce results effectively.

# %%
import math
from pathlib import Path
from types import SimpleNamespace
from tqdm.auto import tqdm
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
from utilities import get_dataloaders

import wandb

# %% [markdown]
# ### Sprite classification
#
# We will build a simple model to classify sprites. You can see some examples of sprites and corresponding classes in the image below.
#
# ![image.png](attachment:image.png)

# %%
INPUT_SIZE = 3 * 16 * 16
OUTPUT_SIZE = 5
HIDDEN_SIZE = 256
NUM_WORKERS = 2
CLASSES = ["hero", "non-hero", "food", "spell", "side-facing"]
DATA_DIR = Path('./data/')
DEVICE = torch.device("cuda" if torch.cuda.is_available()  else "cpu")

def get_model(dropout):
    "Simple MLP with Dropout"
    return nn.Sequential(
        nn.Flatten(),
        nn.Linear(INPUT_SIZE, HIDDEN_SIZE),
        nn.BatchNorm1d(HIDDEN_SIZE),
        nn.ReLU(),
        nn.Dropout(dropout),
        nn.Linear(HIDDEN_SIZE, OUTPUT_SIZE)
    ).to(DEVICE)

# %%
# Let's define a config object to store our hyperparameters
config = SimpleNamespace(
    epochs = 2,
    batch_size = 128,
    lr = 1e-5,
    dropout = 0.5,
    slice_size = 10_000,
    valid_pct = 0.2,
)

# %%
def train_model(config):
    "Train a model with a given config"
    
    wandb.init(
        project="dlai_intro",
        config=config,
    )

    # Get the data
    train_dl, valid_dl = get_dataloaders(DATA_DIR, 
                                         config.batch_size, 
                                         config.slice_size, 
                                         config.valid_pct)
    n_steps_per_epoch = math.ceil(len(train_dl.dataset) / config.batch_size)

    # A simple MLP model
    model = get_model(config.dropout)

    # Make the loss and optimizer
    loss_func = nn.CrossEntropyLoss()
    optimizer = Adam(model.parameters(), lr=config.lr)

    example_ct = 0

    for epoch in tqdm(range(config.epochs), total=config.epochs):
        model.train()

        for step, (images, labels) in enumerate(train_dl):
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            outputs = model(images)
            train_loss = loss_func(outputs, labels)
            optimizer.zero_grad()
            train_loss.backward()
            optimizer.step()

            example_ct += len(images)
            metrics = {
                "train/train_loss": train_loss,
                "train/epoch": epoch + 1,
                "train/example_ct": example_ct
            }
            wandb.log(metrics)
            
        # Compute validation metrics, log images on last epoch
        val_loss, accuracy = validate_model(model, valid_dl, loss_func)
        # Compute train and validation metrics
        val_metrics = {
            "val/val_loss": val_loss,
            "val/val_accuracy": accuracy
        }
        wandb.log(val_metrics)
    
    wandb.finish()

# %%
def validate_model(model, valid_dl, loss_func):
    "Compute the performance of the model on the validation dataset"
    model.eval()
    val_loss = 0.0
    correct = 0

    with torch.inference_mode():
        for i, (images, labels) in enumerate(valid_dl):
            images, labels = images.to(DEVICE), labels.to(DEVICE)

            # Forward pass
            outputs = model(images)
            val_loss += loss_func(outputs, labels) * labels.size(0)

            # Compute accuracy and accumulate
            _, predicted = torch.max(outputs.data, 1)
            correct += (predicted == labels).sum().item()
            
    return val_loss / len(valid_dl.dataset), correct / len(valid_dl.dataset)

# %% [markdown]
# ### W&B account
# The next cell will log you into the Weights and Biases site anonymously, that is without a unique login. You can also sign up for a free account if you wish to save your work, but that is not needed to finish the course.

# %%
wandb.login(anonymous="allow")
# Out:
# wandb: (1) Private W&B dashboard, no account required
# wandb: (2) Use an existing W&B account
# wandb: Enter your choice: 1
# wandb: You chose 'Private W&B dashboard, no account required'
# wandb: Appending key for api.wandb.ai to your netrc file: /home/jovyan/.netrc
# True

# %% [markdown]
# ### Train model
# Let's train the model with default config and check how it's doing in W&B.

# %%
train_model(config)
# Out:
# wandb: Currently logged in as: anony-moose-649157725543428577. Use `wandb login --relogin` to force relogin
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/home/jovyan/work/wandb/run-20240611_074416-d6x51jcm</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/d6x51jcm?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">glorious-pine-1</a></strong> to <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
#  View run at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/d6x51jcm?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/d6x51jcm?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.005 MB of 0.009 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=0.565921…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>████▇█▇▇▆▆▅▅▅▆▅▅▆▅▄▄▅▃▄▄▅▃▃▃▄▃▄▂▂▃▁▂▃▂▃▁</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>1.29024</td></tr><tr><td>val/val_accuracy</td><td>0.5875</td></tr><tr><td>val/val_loss</td><td>1.27359</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glorious-pine-1</strong> at: <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/d6x51jcm?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/d6x51jcm?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240611_074416-d6x51jcm/logs</code>

# %%
# So let's change the learning rate to a 1e-3 
# and see how this affects our results.
config.lr = 1e-4
train_model(config)
# Out:
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/home/jovyan/work/wandb/run-20240611_074439-lyh33pgy</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/lyh33pgy?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">toasty-forest-2</a></strong> to <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
#  View run at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/lyh33pgy?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/lyh33pgy?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>███▇▆▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▂▁▂▁▂▁▁▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>0.41926</td></tr><tr><td>val/val_accuracy</td><td>0.956</td></tr><tr><td>val/val_loss</td><td>0.32054</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">toasty-forest-2</strong> at: <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/lyh33pgy?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/lyh33pgy?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240611_074439-lyh33pgy/logs</code>

# %%
config.lr = 1e-4
train_model(config)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01667050886899233, max=1.0)…
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/home/jovyan/work/wandb/run-20240611_074454-0riz5pji</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/0riz5pji?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">desert-puddle-3</a></strong> to <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
#  View run at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/0riz5pji?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/0riz5pji?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
#   0%|          | 0/2 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁████████████████████</td></tr><tr><td>train/example_ct</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/train_loss</td><td>█▇▇▇▆▆▅▅▄▄▄▃▄▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁█</td></tr><tr><td>val/val_loss</td><td>█▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>2</td></tr><tr><td>train/example_ct</td><td>16000</td></tr><tr><td>train/train_loss</td><td>0.32946</td></tr><tr><td>val/val_accuracy</td><td>0.9575</td></tr><tr><td>val/val_loss</td><td>0.33427</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">desert-puddle-3</strong> at: <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/0riz5pji?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/0riz5pji?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240611_074454-0riz5pji/logs</code>

# %%
config.dropout = 0.1
config.epochs = 1
train_model(config)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016668462318678696, max=1.0…
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/home/jovyan/work/wandb/run-20240611_074512-xo81urqg</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/xo81urqg?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">morning-puddle-4</a></strong> to <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
#  View run at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/xo81urqg?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/xo81urqg?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/example_ct</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/train_loss</td><td>██▇▇▆▇▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▃▃▂▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁</td></tr><tr><td>val/val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/example_ct</td><td>8000</td></tr><tr><td>train/train_loss</td><td>0.47279</td></tr><tr><td>val/val_accuracy</td><td>0.9</td></tr><tr><td>val/val_loss</td><td>0.53334</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">morning-puddle-4</strong> at: <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/xo81urqg?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/xo81urqg?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240611_074512-xo81urqg/logs</code>

# %%
config.lr = 1e-3
train_model(config)
# Out:
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01666847039014101, max=1.0)…
# wandb version 0.17.1 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.15.7
# Run data is saved locally in <code>/home/jovyan/work/wandb/run-20240611_074524-zs6pvecu</code>
# Syncing run <strong><a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/zs6pvecu?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">glamorous-night-5</a></strong> to <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
#  View run at <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/zs6pvecu?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/zs6pvecu?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a>
# Do NOT share these links with anyone. They can be used to claim your runs.
#   0%|          | 0/1 [00:00<?, ?it/s]
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train/example_ct</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇████</td></tr><tr><td>train/train_loss</td><td>█▆▄▄▄▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val/val_accuracy</td><td>▁</td></tr><tr><td>val/val_loss</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>train/epoch</td><td>1</td></tr><tr><td>train/example_ct</td><td>8000</td></tr><tr><td>train/train_loss</td><td>0.07662</td></tr><tr><td>val/val_accuracy</td><td>0.993</td></tr><tr><td>val/val_loss</td><td>0.05672</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">glamorous-night-5</strong> at: <a href='https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/zs6pvecu?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803' target="_blank">https://wandb.ai/anony-moose-649157725543428577/dlai_intro/runs/zs6pvecu?apiKey=f4518a2246c8d749a1acfac86045b750f32d8803</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240611_074524-zs6pvecu/logs</code>
